# %% [markdown]
# # Create a Class with instance attributes

# %%
class Student:
    def __init__(self,id,name):
        self.id=id
        self.name=name
    def show(self):
        print('Name',self.name,'id',self.id)
s1=Student('Minhaj',23)
s1.show()
# Out:
# Name 23 id Minhaj

# %% [markdown]
# # Create a Vehicle class without any variables and methods

# %%
class Variable:
    pass

# %% [markdown]
# # Create a child class Bus that will inherit all of the variables and methods of the Vehicle class
# Given:
#
# class Vehicle:
#
#     def __init__(self, name, max_speed, mileage):
#         self.name = name
#         self.max_speed = max_speed
#         self.mileage = mileag

# %%
class Vehicle:

    def __init__(self, name, max_speed, mileage):
        self.name = name
        self.max_speed = max_speed
        self.mileage = mileage

class Bus(Vehicle):
    
    pass

School_bus=Bus("BMW",178,12)
print(School_bus.name,School_bus.max_speed,School_bus.mileage)
# Out:
# BMW 178 12

# %% [markdown]
# # Class and instance variable

# %%
class Employee:
    company_name="XYZ Company"
    def __init__(self,name,salary):
        self.name=name
        self.salary=salary

e1=Employee('Michael',20000)
print('Employee',e1.name,e1.salary)
print('Company name',Employee.company_name)

e1.name="John"
e1.salary=40000
print('Employee',e1.name,e1.salary)

Employee.company_name='ABC Company'
print('Modify Company name',Employee.company_name)
# Out:
# Employee Michael 20000
# Company name XYZ Company
# Employee John 40000
# Modify Company name ABC Company

# %% [markdown]
# # Default Constructor

# %%
class Employee:

    def display(self):
        print('Inside Display')

emp = Employee()
emp.display()
# Out:
# Inside Display

# %% [markdown]
# # unParameterized Constructor

# %%
class Company:

    # no-argument constructor
    def __init__(self):
        self.name = "PYnative"
        self.address = "ABC Street"

    # a method for printing data members
    def show(self):
        print('Name:', self.name, 'Address:', self.address)

# creating object of the class
cmp = Company()

# calling the instance method using the object
cmp.show()
# Out:
# Name: PYnative Address: ABC Street

# %% [markdown]
# # Parameterized Constructor

# %%
class Employee:
    # parameterized constructor
    def __init__(self, name, age, salary):
        self.name = name
        self.age = age
        self.salary = salary

    # display object
    def show(self):
        print(self.name, self.age, self.salary)

# creating object of the Employee class
emma = Employee('Emma', 23, 7500)
emma.show()

kelly = Employee('Kelly', 25, 8500)
kelly.show()
# Out:
# Emma 23 7500
# Kelly 25 8500

# %% [markdown]
# # Constructor Chaining

# %%
class Vehicle:
    # Constructor of Vehicle
    def __init__(self, engine):
        print('Inside Vehicle Constructor')
        self.engine = engine

class Car(Vehicle):
    # Constructor of Car
    def __init__(self, engine, max_speed):
        super().__init__(engine)
        print('Inside Car Constructor')
        self.max_speed = max_speed

class Electric_Car(Car):
    # Constructor of Electric Car
    def __init__(self, engine, max_speed, km_range):
        super().__init__(engine, max_speed)
        print('Inside Electric Car Constructor')
        self.km_range = km_range

# Object of electric car
ev = Electric_Car('1500cc', 240, 750)
print(f'Engine={ev.engine}, Max Speed={ev.max_speed}, Km range={ev.km_range}')
# Out:
# Inside Vehicle Constructor
# Inside Car Constructor
# Inside Electric Car Constructor
# Engine=1500cc, Max Speed=240, Km range=750

# %% [markdown]
# # Encapsulation

# %% [markdown]
# Public Member

# %%
class Employee:
    # constructor
    def __init__(self, name, salary):
        # public data members
        self.name = name
        self.salary = salary

    # public instance methods
    def show(self):
        # accessing public data member
        print("Name: ", self.name, 'Salary:', self.salary)

# creating object of a class
emp = Employee('Jessa', 10000)

# accessing public data members
print("Name: ", emp.name, 'Salary:', emp.salary)

# calling public method of the class
emp.show()
# Out:
# Name:  Jessa Salary: 10000
# Name:  Jessa Salary: 10000

# %% [markdown]
# Private Member

# %%
class Employee:
    # constructor
    def __init__(self, name, salary):
        # public data member
        self.name = name
        # private member
        self.__salary = salary

# creating object of a class
emp = Employee('Jessa', 10000)

# accessing private data members
print('Salary:', emp.__salary)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 13
#      10 emp = Employee('Jessa', 10000)
#      12 # accessing private data members
# ---> 13 print('Salary:', emp.__salary)
#
# AttributeError: 'Employee' object has no attribute '__salary'

# %%
# We can access private members from outside of a class using the following two approaches

# Create public method to access private members
# Use name mangling

class Employee:
    # constructor
    def __init__(self, name, salary):
        # public data member
        self.name = name
        # private member
        self.__salary = salary

    # public instance methods
    def show(self):
        # private members are accessible from a class
        print("Name: ", self.name, 'Salary:', self.__salary)

# creating object of a class
emp = Employee('Jessa', 10000)

# calling public method of the class
emp.show()
# Out:
# Name:  Jessa Salary: 10000

# %%
class Student:
    # class variable
    school_name = 'ABC School'

    # constructor
    def __init__(self, name, age):
        # instance variables
        self.name = name
        self.age = age

    # instance method
    def show(self):
        # access instance variables and class variables
        print('Student:', self.name, self.age, Student.school_name)

    # instance method
    def change_age(self, new_age):
        # modify instance variable
        self.age = new_age

    # class method
    @classmethod
    def modify_school_name(cls, new_name):
        # modify class variable
        cls.school_name = new_name

s1 = Student("Harry", 12)

# call instance methods
s1.show()
s1.change_age(14)

# call class method
Student.modify_school_name('XYZ School')
# call instance methods
s1.show()
# Out:
# Student: Harry 12 ABC School
# Student: Harry 14 XYZ School

# %%
class Employee:
    # constructor
    def __init__(self, name, salary):
        # public data member
        self.name = name
        # private member
        self.__salary = salary

# creating object of a class
emp = Employee('Jessa', 10000)

print('Name:', emp.name)
# direct access to private member using name mangling
print('Salary:', emp._Employee__salary)
# Out:
# Name: Jessa
# Salary: 10000

# %% [markdown]
# # Single inheritance

# %%
# In single inheritance, a child class inherits from a single-parent class. Here is one child class and one parent class.
class Vehical:
    def Vehical_data(self):
        print('Inside vehical class')
class Car(Vehical):
    def Car_data(self):
        print('Inside car class')
obj=Car()
obj.Car_data()
obj.Vehical_data()
# Out:
# Inside car class
# Inside vehical class

# %% [markdown]
# # multiple inheritance:

# %%
class Parent1:
    def person_data(self,name,age):
        print('Inside person 1')
        print('Name:',name,';age',age)
class Parent2:
    def person2_data(self,company,location):
        print('Inside person 2')
        print('Company name:',company,';location:',location)
class Child(Parent1,Parent2):
    def child_data(self,salary,skill):
        print('Inside child class')
        print('Salary:',salary,';skills',skill)
emp=Child()
emp.person_data('suraiya',23)
emp.person2_data('microsoft','mumbai')
emp.child_data(40000,'developer')
# print(Child.mro())
# Out:
# Inside person 1
# Name: suraiya ;age 23
# Inside person 2
# Company name: microsoft ;location: mumbai
# Inside child class
# Salary: 40000 ;skills developer

# %% [markdown]
# # Multilevel inheritance:

# %%
class Grandfather:
    def person(self):
        print('inside grandfather class')
class Father(Grandfather):
    def person2(self):
        print('inside father class')
class Son(Father,Grandfather):
    def person3(self):
        print('inside son class ')
obj=Son()
obj.person()
obj.person2()
obj.person3()
print(Son.mro())
# Out:
# inside grandfather class
# inside father class
# inside son class
# [<class '__main__.Son'>, <class '__main__.Father'>, <class '__main__.Grandfather'>, <class 'object'>]

# %% [markdown]
# # Hierarchical inheritance:

# %%
class father:
    def info(self):
        print('inside main class')
class brother1(father):
    def brother1(self,name):
        print('inside brother1 class',name)
class brother2(father):
    def brother2(self,age):
        print('inside brother2 class',age)
obj=brother1()
obj.info()
obj.brother1('munazzir')
obj2=brother2()
obj2.info()
# Out:
# inside main class
# inside brother1 class munazzir
# inside main class

# %% [markdown]
# # Hybrid inheritance:

# %%
class Parent:
    def vehical_data(self):
        print('inside vehical data')
class Child1(Parent):
    def car_data(self):
        print('inside car data')
class Child2(Parent):
    def truck_data(self):
        print('inside truck data')
class Child3(Child1,Parent):
    def sports_data(self):
        print('inside sports data')
s=Child3()
s.car_data()
# s.truck_data()
s.sports_data()
s.vehical_data()
# Out:
# inside car data
# inside sports data
# inside vehical data

# %%
class Emp:
    def __init__(self,name,id):
        self.name=name
        self.id=id
    def show(self):
        print('emp name is',self.name,self.id)
class Emp2(Emp1):
    def __init__(self,name,id,age):
        self.age=age
        super().__init__(name,id)
        s1=super().show()
        print('emp 2 is having age also',self.age)
obj=Emp2('suraiya',163,90)
print(obj.name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [14], in <cell line: 7>()
#       5     def show(self):
#       6         print('emp name is',self.name,self.id)
# ----> 7 class Emp2(Emp1):
#       8     def __init__(self,name,id,age):
#       9         self.age=age
#
# NameError: name 'Emp1' is not defined

# %%
class Teacher:
    def __init__(self,name,rollno):
        self.name=name
        self.rollno=rollno
    def show(self):
        print('student name is:',self.name,'roll no:',self.rollno)
class Student(Teacher):
    def __init__(self,name,rollno,age):
        self.age=age
        super().__init__(name,rollno)
        var=super().show()
    def show(self):
        self.school='abc school'
        print('school name:',self.school,'age:',self.age)
s1=Student('suraiya',35,23)
s1.show()
# Out:
# student name is: suraiya roll no: 35
# school name: abc school age: 23

# %%
class base():
    def __init__(self):
        self.var = 10
        
    def add(self, num):
        res = self.var+num
        return res
    
class inherit(base):
    def __init__(self, num=10):
        x = super().add(num)

a = inherit()
print(a)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [2], in <cell line: 13>()
#      10     def __init__(self, num=10):
#      11         x = super().add(num)
# ---> 13 a = inherit()
#      14 print(a)
#
# Input In [2], in inherit.__init__(self, num)
#      10 def __init__(self, num=10):
# ---> 11     x = super().add(num)
#
# Input In [2], in base.add(self, num)
#       5 def add(self, num):
# ----> 6     res = self.var+num
#       7     return res
#
# AttributeError: 'inherit' object has no attribute 'var'

# %%
class student:    
    def __init__(self,name,rollno):
        self.name=name
        self.rollno=rollno
    def show(self):
        return "Name of the student:",self.name,"Roll no of the student:",self.rollno
class school(student):
    def __init__(self, name, rollno,age):
        super().__init__(name, rollno)       
        self.age = age
        zikra = super().show()
    def show(self):
        self.school="abp school"
        "school name:",self.school, "rollno.:",self.rollno, "age:", self.age  
class home(school):
    def __init__(self, name, rollno,age, subject):
        super().__init__(name, rollno, age)
        self.subject = subject     
    def show(self):
        zikra = super().show()
        self.school="abp school"
        return "school name:",self.school, "rollno.:",self.rollno, "subject:", self.subject,zikra 
s1=home('iram',55,33,"Maths")
s1.show()
# Out:
# ('school name:', 'abp school', 'rollno.:', 55, 'subject:', 'Maths', None)

# %%
class A:
    def __init__(self,name):
        self.name=name
    def show(self):
        print("name :",self.name)
class B(A):
    def __init__(self,name,rollno):
        super().__init__(name)
        x=super().show()
        self.rollno=rollno
    def show(self):
        self.school="abp school"
        print=("school name:",self.school, "rollno.:",self.rollno)  
class C(B):
    def __init__(self,name,rollno,subject):
        
        super().__init__(name,rollno)
        x=super().show()

        
        self.subject=subject
    def show(self):
        self.school="abp school"
        print=("school name:",self.school, "rollno.:",self.rollno,"subject: ",self.subject) 
s1=C("iram",22,"english")  
s1.show()

# %%
class Company:
    def company_name(self):
        return 'Google'

class Employee(Company):
    def info(self):
        # Calling the superclass method using super()function
        c_name = super().company_name()
        print("Jessa works at", c_name)

# Creating object of child class
emp = Employee()
emp.info()
# Out:
# Jessa works at Google

# %%
lst=list ((2,3,4))
print(lst)
# Out:
# [2, 3, 4]

# %%
lst=list (2,3,4)
print(lst)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 lst=list (2,3,4)
#       2 print(lst)
#
# TypeError: list expected at most 1 argument, got 3

# %% [markdown]
# # issubclass:

# %%
class College:
    def func1(self):
        print("Inside parent class")

class School(College):
    def func2(self):
        print("Inside child class")

class Institute:
    def func3(self):
        print("Inside parent class")

print(issubclass(School,College)) #school is a sub class(child class) of college
print(issubclass(School,list))
print(issubclass(Institute,College))
print(issubclass(School,(list,College)))
print(issubclass(School,School))
print(issubclass(School,(int,School)))
# Out:
# True
# False
# False
# True
# True
# True

# %%
class Vehicle:
    def max_speed(self):
        print("max speed is 100 Km/Hour")

class Car(Vehicle):
#     pass
    # overridden the implementation of Vehicle class
    def max_speed(self):
        print("max speed is 200 Km/Hour")

# Creating object of Car class
car = Car()
car.max_speed()
# Out:
# max speed is 200 Km/Hour

# %%
class A:
    def process(self):
        print(" In class A")

class B(A):
    def process(self):
        print(" In class B")

class C(B, A):
    def process(self):
        print(" In class C")

# Creating object of C class
C1 = C()
C1.process()
print(C.mro())
# Out:
#  In class C
# [<class '__main__.C'>, <class '__main__.B'>, <class '__main__.A'>, <class 'object'>]

# %%
class Grandfather:
    def person(self):
        print('inside grandfather class')
class Father(Grandfather):
    def person2(self):
        print('inside father class')
class Son(Father,Grandfather):
    def person3(self):
        print('inside son class ')
obj=Son()
obj.person()
obj.person2()
obj.person3()
print(Son.mro())
# Out:
# inside grandfather class
# inside father class
# inside son class
# [<class '__main__.Son'>, <class '__main__.Father'>, <class '__main__.Grandfather'>, <class 'object'>]

# %%
class A:
    def rk(self):
        print(" In class A")
class B(A):
    def rk(self):
        print(" In class B")
class C(A):
    def rk(self):
        print("In class C")
 
# classes ordering
class D(B, C):
    pass
    
r = D()
r.rk
# Out:
# <bound method B.rk of <__main__.D object at 0x0000025AFC397FA0>>

# %%
# how many times object and refrence variable will be there at end line 11
class Table:
    def __init__(self):
        self.no_of_legs=4
        self.glass_top=None
        self.wooden_top=None
dining_table=Table()
back_table=Table()
front_table=back_table
back_table=dining_table
dining_table=front_table
front_table=back_table  #11

# %%
print(50/8-3*2+8)
# Out:
# 8.25

# %%
class A:
    def process(self):
        print(" In class A")

class B(A):
    def process(self):
        print(" In class B")

class C(A,B):
    def process(self):
        print(" In class C")

# Creating object of C class
C1 = C()
C1.process()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 9>()
#       6     def process(self):
#       7         print(" In class B")
# ----> 9 class C(A,B):
#      10     def process(self):
#      11         print(" In class C")
#
# TypeError: Cannot create a consistent method resolution
# order (MRO) for bases A, B

# %%
class Parent:
     def func1(self):
         print("this is function 1")
class Child(Parent):
     def func2(self):
          super().func1()
          print("this is function 2")
 
obj = Child()
obj.func2()
# Out:
# this is function 1
# this is function 2

# %%
class Company:
    def company_name(self):
        return 'Google'

class Employee(Company):
    def info(self):
        # Calling the superclass method using super()function
#         c_name = super().company_name()
#         print("Jessa works at", c_name)
        print("Jessa works at")
        

# Creating object of child class
emp = Employee()
emp.info()
# Out:
# Jessa works at

# %%
class A:
    def process(self):
        print(" In class A")

class B(A):
    def process(self):
        print(" In class B")

class C(B, A):
    def process(self):
        print(" In class C")

# Creating object of C class
C1 = C()
C1.process()
# print(C.mro())
# Out:
#  In class C

# %%
# Parent class 1
class Person:
    def person_info(self, name, age):
        print('Inside Person class')
        print('Name:', name, 'Age:', age)

# Parent class 2
class Company:
    def company_info(self, company_name, location):
        print('Inside Company class')
        print('Name:', company_name, 'location:', location)

# Child class
class Employee(Person, Company):
    def Employee_info(self, salary, skill):
        print('Inside Employee class')
        print('Salary:', salary, 'Skill:', skill)
class Demployee(Person, Company):
    def Employee_info(self, salary, skill):
        print('Inside Employee class')
        print('Salary:', salary, 'Skill:', skill)

# Create object of Employee
emp = Employee()
demp1=Demployee()

# access data
emp.person_info('Jessa', 28)
emp.company_info('Google', 'Atlanta')
emp.Employee_info(12000, 'Machine Learning')
emp.person_info('markin', 28)
# Out:
# Inside Person class
# Name: Jessa Age: 28
# Inside Company class
# Name: Google location: Atlanta
# Inside Employee class
# Salary: 12000 Skill: Machine Learning
# Inside Person class
# Name: markin Age: 28

# %%
# a=36/4
print(36/4)
# Out:
# 9.0

# %%
class Add:
    def result(self,a,b):
        print('Adition',a+b)
class Multi(Add):
#     pass
    def result(self,a,b):
        print('Mltiplication',a*b)
m=Multi()
m.result(5,4)
# Out:
# Mltiplication 20

# %%
class Vehicle:

    def __init__(self, name, color, price):
        self.name = name
        self.color = color
        self.price = price

    def show(self):
        print('Details:', self.name, self.color, self.price)

    def max_speed(self):
        print('Vehicle max speed is 150')

    def change_gear(self):
        print('Vehicle change 6 gear')


# inherit from vehicle class
class Car(Vehicle):
#     def max_speed(self):
#         print('Car max speed is 240')

    def change_gear(self):
        print('Car change 7 gear')


# Car Object
car = Car('Car x1', 'Red', 20000)
car.show()
# calls methods from Car class
car.max_speed()
car.change_gear()

# Vehicle Object
vehicle = Vehicle('Truck x1', 'white', 75000)
vehicle.show()
# calls method from a Vehicle class
vehicle.max_speed()
vehicle.change_gear()
# Out:
# Details: Car x1 Red 20000
# Vehicle max speed is 150
# Car change 7 gear
# Details: Truck x1 white 75000
# Vehicle max speed is 150
# Vehicle change 6 gear

# %%
class Scorpio:
    def fuel(self):
        print('fuel in scorpio')
    def speed(self):
        print('speed in scorpio is 340')
class BMW:
    def fuel(self):
        print('fuel in bmw')
    def speed(self):
        print('speed in bmw is 250')
a=Scorpio()
b=BMW()
for car in (a,b):
    car.fuel()
    car.speed()
# Out:
# fuel in scorpio
# speed in scorpio is 340
# fuel in bmw
# speed in bmw is 250

# %%
class Shopping:
    def __init__(self, basket, buyer):
        self.basket = list(basket)
        self.buyer = buyer

    def __len__(self):
        print('Redefine length')
        count = len(self.basket)
        # count total items in a different way
        # pair of shoes and shir+pant
        return count *2

shopping = Shopping(['Shoes','dress'], 'Jessa')
print(len(shopping))
# Out:
# Redefine length
# 4

# %%
student=['jerry','herry','lerry']
school='ABC School'
print('Reverse string')
for i in reversed(student):
    print(i,end=' ')
    
print('\nReverse list')
for j in reversed(['a','s','d','f']):
    print(j,end=' ')
# Out:
# Reverse string
# lerry herry jerry
# Reverse list
# f d s a

# %%
def addition(a, b):
    c = a + b
    print(c)


def addition(a, b, c):
    d = a + b + c
    print(d)


# the below line shows an error
addition(4, 5)

# This line will call the second product method
addition(3, 7, 5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [14], in <cell line: 12>()
#       8     print(d)
#      11 # the below line shows an error
# ---> 12 addition(4, 5)
#      14 # This line will call the second product method
#      15 addition(3, 7, 5)
#
# TypeError: addition() missing 1 required positional argument: 'c'

# %%
for i in range(4):print(i,end=' ')
print()
for i in range(5,10):print(i,end=' ')
print()
for i in range(1,10,2):print(i,end=' ')
# Out:
# 0 1 2 3
# 5 6 7 8 9
# 1 3 5 7 9

# %%
class Shape:
    def area(self,a,b=0):
        if b>0:
            print('Area of rectangle is',a*b)
        else:
            print('Area of square is',a**2)
sqr=Shape()
sqr.area(5)

rec=Shape()
rec.area(5,4)
# Out:
# Area of square is 25
# Area of rectangle is 20

# %%
# add 2 numbers
print(100 + 200)

# concatenate two strings
print('Jess' + 'Roy')

# merger two list
print([10, 20, 30] + ['jessa', 'emma', 'kelly'])
# Out:
# 300
# JessRoy
# [10, 20, 30, 'jessa', 'emma', 'kelly']

# %%
print(550+330)
print('jessy'+'roy')
print([10,20]+['a','b'])
# Out:
# 880
# jessyroy
# [10, 20, 'a', 'b']

# %%
class Textbook:
    def __init__(self,pages):
        self.pages=pages
b1=Textbook(200)
b2=Textbook(300)
print(b1+b2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [8], in <cell line: 6>()
#       4 b1=Textbook(200)
#       5 b2=Textbook(300)
# ----> 6 print(b1+b2)
#
# TypeError: unsupported operand type(s) for +: 'Textbook' and 'Textbook'

# %%
class Book:
    def __init__(self, pages):
        self.pages = pages

    # Overloading + operator with magic method
    def __add__(self, other):
        return self.pages + other.pages

b1 = Book(400)
b2 = Book(300)
print("Total number of pages: ", b1 + b2)
# Out:
# Total number of pages:  700

# %%
class Employee:
    def __init__(self, , salary):
        self.myname = name
        self.salary = salary

    def __mul__(self, timesheet):
        print('Worked for', timesheet.days, 'days')
        # calculate salary
        return self.salary * timesheet.days


class TimeSheet:
    def __init__(self, name, days):
        self.name = name
        self.days = days


emp = Employee("Jessa", 800)
timesheet = TimeSheet("minhaj", 50)
print("salary is: ", emp * timesheet)
# Out:
# Worked for 50 days
# salary is:  40000

# %%
class Employee:
    def __init__(self, jessa, salary):
        self.name = jessa
        self.salary = salary
emp = Employee("Jessa", 800)
emp2 = Employee("wessa", 800)
emp3 = Employee("kessa", 800)

# timesheet = TimeSheet("Jessa", 50)
# print("salary is: ", emp * timesheet)
# print("salary is: ", emp2 * timesheet)
print("name:" ,emp3.name)
# Out:
# name: kessa

# %%
class Employee:
    def __init__(self, name, salary):
        self.name = name
        self.salary = salary
#     def __mul__(self, timesheet):
#         print('Worked for', timesheet.days, 'days')
#         # calculate salary
#         return self.salary * timesheet.days
class TimeSheet:
    def __init__(self, name, days):
        self.name = name
        self.days = days
emp = Employee("Jessa", 800)
timesheet = TimeSheet("Jessa", 50)
print("salary is: ", emp * timesheet)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [17], in <cell line: 15>()
#      13 emp = Employee("Jessa", 800)
#      14 timesheet = TimeSheet("Jessa", 50)
# ---> 15 print("salary is: ", emp * timesheet)
#
# TypeError: unsupported operand type(s) for *: 'Employee' and 'TimeSheet'

# %%
class Employee:
    def __init__(self, name, salary):
        self.name = name
        self.salary = salary
#     def __mul__(self, timesheet):
#         print('Worked for', timesheet.days, 'days')
#         # calculate salary
#         return self.salary * timesheet.days
class TimeSheet:
    def __init__(self, name, days):
        self.name = name
        self.days = days
emp = Employee()
timesheet = TimeSheet("Jessa", 50)
# print("salary is: ", emp * timesheet)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [18], in <cell line: 13>()
#      11         self.name = name
#      12         self.days = days
# ---> 13 emp = Employee()
#      14 timesheet = TimeSheet("Jessa", 50)
#
# TypeError: Employee.__init__() missing 2 required positional arguments: 'name' and 'salary'

# %%
class Employee:
    def __init__(self, name, salary):
        self.name = name
        self.salary = salary
    def __mul__(self):
        print('Worked for', self.days, 'days')
        # calculate salary
        return self.salary * self.days
class TimeSheet:
    def __init__(self, name, days):
        self.name = name
        self.days = days
emp = Employee("Jessa", 800)
timesheet = TimeSheet("Jessa", 50)
print("salary is: ", emp * timesheet)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [23], in <cell line: 16>()
#      14 emp = Employee("Jessa", 800)
#      15 timesheet = TimeSheet("Jessa", 50)
# ---> 16 print("salary is: ", emp * timesheet)
#
# TypeError: Employee.__mul__() takes 1 positional argument but 2 were given

# %%
a=2
b='abcd'
c=33
tp=a,b,c
print(tp)
print(type(tp))
# Out:
# (2, 'abcd', 33)
# <class 'tuple'>

# %%
tp={2,'minhaj',22,'bhai'}
w,x,y,z=tp
print(w)
print(x)
print(y)
print(z)
print(tp)
print(type(tp))
# Out:
# 2
# minhaj
# bhai
# 22
# {2, 'minhaj', 'bhai', 22}
# <class 'set'>

# %% [markdown]
# # Magic method

# %%
num=10
print(num + 5)
print(num.__add__(5))
# Out:
# 15
# 15

# %%
print(num.__add__(5))
# print(num.__add__(10))
# Out:
# 15

# %%
class distance:
    def __init__(self, x=None,y=None):
        self.ft=x
        self.inch=y
        
    def __add__(self,other):
        
        temp=distance()
#         print(temp.__dict__)
        
        temp.ft=self.ft+other.ft
        temp.inch=self.inch+other.inch
#         
#         print(temp.__dict__)
        
        if temp.inch>=12:
            temp.ft+=1
            temp.inch-=12
            return temp
#             return (temp.ft,temp.inch)
    def __str__(self):
        return 'ft:'+str(self.ft)+' in: '+str(self.inch)

d1=distance(3,10)
d2=distance(4,4)
# print("d1= {} d2={}".format(d1, d2))
print('d2',d2)
d3=d1+d2
print(d3)
# Out:
# d2 ft:4 in: 4
# ft:8 in: 2

# %%
class A:
    def __init__(self):
        print(123)
    def __new__(self):
        print(456)
S1=A()
# Out:
# 456

# %%
class student:
#     def __new__(self,name):
#         self.name=name
#         print("new")
#         print(self.name)
        
    def __init__(self,name):
        self.name=name
        print("init")
        print(self.name)
s1=student("Minhaj")
# Out:
# init
# Minhaj

# %%
class Demo:
    def __new__(cls, *args):
        print("__new__ called")
        return object.__new__(cls)

    def __init__(self):
        print("__init__ called")

d = Demo()
# Out:
# __new__ called
# __init__ called

# %%
class Book:
    def __init__(self, pages):
        self.pages = pages

    # Overloading + operator with magic method
    def __add__(self, other):
#         self=b1
        # others=b2
        return self.pages + other.pages

b1 = Book(400)
b2 = Book(300)
print("Total number of pages: ", b1 + b2)
print(b1.pages)
# Out:
# Total number of pages:  120000
# 400

# %%
class Student:
    def __init__(self,name,age):
        self.name=name
        self.age=age
        
    def __add__(self,other):
        return self.age+other.age
    
    def __mul__(self,other):
        return self.age * other.age
    
    
s1=Student("Junaid",23)
s2=Student("Sarfraz",25)
print(s1*s2)
# Out:
# 575

# %%
s1+s2
s1*s2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 s1+s2
#       2 s1*s2
#
# TypeError: unsupported operand type(s) for +: 'Student' and 'Student'

# %%
s1.__dict__
# Out:
# {'name': 'Junaid', 'age': 23}

# %%
# int=5
str2="12"
print(int(str2))

print(int)
# Out:
# 12
# <class 'int'>

# %%
class Student:
    def __init__(self,name,age):
        self.name=name
        self.age=age
        
s1=Student("adnan",20)
s2=Student("bilal",22)
print(s1.__dict__)
print(s2.__dict__)
# print(s1+s2)
print(s1.name+" "+s2.name)
# Out:
# {'name': 'adnan', 'age': 20}
# {'name': 'bilal', 'age': 22}
# adnan bilal

# %%
input1=input("Enter your input 1 : ")
input2=input("Enter your input 2 : ")

answer=input1+input2
print(input1,type(input1),input2,type(input2))
print(answer,type(answer))
print(input1==input2,type(input1==input2))

sum=int(input1)+int(input2)
print(sum,type(sum))

exponent=int(input1)**int(input2)
print(exponent,type(exponent))
# Out:
# Enter your input 1 : 3
# Enter your input 2 : 4
# 3 <class 'str'> 4 <class 'str'>
# 34 <class 'str'>
# False <class 'bool'>
# 7 <class 'int'>
# 81 <class 'int'>

# %%
class GameProtagonist:
    def __init__(self):
        self.health = 100
        self.mana = 100
        self.level = 1

    def take_damage(self):
        self.health -= 10

player_one = GameProtagonist()
player_one.health
# Out:
# 100

# %%
class Employee:
    @staticmethod
    def sample(x):
        print('Inside static method', x)

# call static method
Employee.sample(10)

# can be called using object
emp = Employee()
emp.sample(30)
# Out:
# Inside static method 10
# Inside static method 30
