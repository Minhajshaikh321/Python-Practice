# %% [markdown]
# # isinstance()

# %%
# The isinstance() function checks if the object (first argument) is an instance or subclass of 
# classinfo class (second argument).

num_list=[1,2,3,4,5]
num_tuple=(1,2,3,4)
list_data=isinstance(num_list,list)
tuple_data=isinstance(num_tuple,list)
# tuple_data=isinstance(num_tuple,tuple)


print(list_data)
print(tuple_data)
# Out:
# True
# False

# %%
class Foo:
  a = 5
  
fooInstance = Foo()

print(isinstance(fooInstance, Foo))
print(isinstance(fooInstance, (list, tuple)))
print(isinstance(fooInstance, (list, tuple, Foo)))
# Out:
# True
# False
# True

# %%
numbers=[11,12,13,14,15]
result=isinstance(numbers,list)
print(numbers,'isinstance of list',result)

result=isinstance(numbers,dict)
print(numbers,'isinstance of dict',result)

result=isinstance(numbers,(list,tuple))
print(numbers,'isinstance of list or tuple',result)

result=isinstance(numbers,(int,tuple))
print(numbers,'isinstance of int or tuple',result)
# Out:
# [11, 12, 13, 14, 15] isinstance of list True
# [11, 12, 13, 14, 15] isinstance of dict False
# [11, 12, 13, 14, 15] isinstance of list or tuple True
# [11, 12, 13, 14, 15] isinstance of int or tuple False

# %% [markdown]
# # abs()

# %%
# The abs() function returns the absolute value of the given number.
# If the number is a complex number, abs() returns its magnitude.

num=-8
absolute_num=abs(num)
print(absolute_num)
# Out:
# 8

# %%
# random integer
integer = -20
print('Absolute value of -20 is:', abs(integer))

#random floating number
floating = -30.33
print('Absolute value of -30.33 is:', abs(floating))
# Out:
# Absolute value of -20 is: 20
# Absolute value of -30.33 is: 30.33

# %%
# random complex number
complex = (3 - 4j)
# |a+bi|=√a2+b2
print('Magnitude of 3 - 4j is:', abs(complex))
# Out:
# Magnitude of 3 - 4j is: 5.0

# %% [markdown]
# # any()

# %%
# The any() function returns True if any element of an iterable is True. If not, it returns False.
booleanlist=[True,False]
result=any(booleanlist)
print(result)
# Out:
# True

# %%
element=[1,2,4,6,0]
print(any(element))

element2=[0,0,0]
print(any(element2))

element3=[0,False]
print(any(element3))

element4=[1,False]
print(any(element4))
# Out:
# True
# False
# False
# True

# %%
s=""
print(any(s))

st="000"
print(any(st))
# Out:
# False
# True

# %%
# In the case of dictionaries, if all keys (not values) are false or the dictionary is empty, any() returns False.
# If at least one key is true, any() returns True.
d={0:'False'}
print(any(d))

d1={'0':'False'}
print(any(d1))

d2={0:4,1:0}
print(any(d2))
# Out:
# False
# True
# True

# %% [markdown]
# # all()

# %%
boolean_list = ['True', 'True', 'True']
# check if all elements are true
result = all(boolean_list)
print(result)

boolean_list2 = [False, 'True', 'True']
# check if all elements are true
result = all(boolean_list2)
print(result)
# Out:
# True
# False

# %%
element=[1,2,4,6]
print(all(element))

element2=[23,12,0]
print(all(element2))

element3=[0,False]
print(all(element3))

element4=[1,False]
print(all(element4))
# Out:
# True
# False
# False
# False

# %%
d={0:'False'}
print(all(d))

d1={'0':'False'}
print(all(d1))

d2={0:4,1:0}
print(all(d2))
# Out:
# False
# True
# False

# %% [markdown]
# # bool()

# %%
# The bool() method takes a specified argument and returns its boolean value.
test=1
print(test,'is',bool(test))

test2=""
print(test2,'is',bool(test2))

test3=True
print(test3,'is',bool(test3))

test4=False
print(test4,'is',bool(test4))

test5=None
print(test5,'is',bool(test5))
# Out:
# 1 is True
#  is False
# True is True
# False is False
# None is False

# %%
# The bytes() method returns an immutable bytes object initialized with the given size and data.
message = 'Python is fun'

# convert string to bytes
byte_message = bytes(message, 'utf-8')
print(byte_message)

# Output: b'Python is fun'
# Out:
# b'Python is fun'

# %%
class Coordinate:
    x=10
    y=-3
points=Coordinate()
print(points.x)
print(points.y)
# Out:
# 10
# -3

# %%
delattr(Coordinate,'y')
print(points.x)
print(point.y)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 delattr(Coordinate,'y')
#       2 print(points.x)
#       3 print(point.y)
#
# AttributeError: y

# %% [markdown]
# # getattr()

# %%
#The getattr() method returns the value of the named attribute of an object. If not found, it returns the default value
#provided to the function.


class Student:
    name='John'
    mark=20
    
person=Student()


name=getattr(person,'name')
name2=person.name
print(name)
print(name2)

mark=getattr(person,'mark')
print(mark)
# Out:
# John
# John
# 20

# %% [markdown]
# # hasattr()

# %%
# The hasattr() method returns true if an object has the given named attribute and false if it does not.
class Fruit:
    price=100
    name="mango"
    
fruit=Fruit()    

print('Fruit price', hasattr(Fruit,'price'))
print('Fruit name', hasattr(Fruit,'name'))
print('Fruit color', hasattr(Fruit,'color'))
# Out:
# Fruit price True
# Fruit name True
# Fruit color False

# %%
class Earphone:
    brand='boat'
    price=2000
earphone=Earphone()

setattr(earphone,'price',3000)
print(earphone.price)

setattr(earphone,'brand','noise')
print(earphone.brand)
# Out:
# 3000
# noise

# %% [markdown]
# # slice()

# %%
# The slice() function returns a slice object that is used to slice any sequence (string, tuple, list, range, or bytes).
text = 'Python Programing'

# get slice object to slice Python
sliced_text = slice(6)
print(text[sliced_text])

# Output: Python
# Out:
# Python

# %%
py_string = 'PythonCode'

# start = -1, stop = -4, step = -1
# contains indices -1, -2 and -3
slice_object = slice(-1, -4, -1)

print(py_string[slice_object])   # noh
# Out:
# edo

# %% [markdown]
# # sorted()

# %%
# The sorted() function sorts elements of a given iterable in specific order (ascending or descending) and returns it as a list.
numbers = [4, 2, 12, 8]

sorted_numbers = sorted(numbers)
print(sorted_numbers)

# Output: [2, 4, 8, 12]
# Out:
# [2, 4, 8, 12]

# %%
py_string='Python'
print(sorted(py_string))
# Out:
# ['P', 'h', 'n', 'o', 't', 'y']

# %% [markdown]
# # sum()

# %%
numbers = [4, 2, 12, 8]
print(sum(numbers))
# Out:
# 26

# %% [markdown]
# # tuple()

# %%
t1=tuple()
t2=tuple([7,3,4])
t3=tuple('minhaj')
t4=tuple({'alphabet':"S","word":"Suraiya"})

print(t1)
print(t2)
print(t3)
print(t4)
# Out:
# ()
# (7, 3, 4)
# ('m', 'i', 'n', 'h', 'a', 'j')
# ('alphabet', 'word')

# %% [markdown]
# # type()

# %%
prime_numbers = [2, 3, 5, 7]

# check type of prime_numbers
result = type(prime_numbers)
print(result)

# Output: <class 'list'>
# Out:
# <class 'list'>

# %%
st='SHAIKHMINHAJ'
print(st[5:-9:-1])
# Out:
# HK

# %% [markdown]
# # range()

# %%
# The range() function returns a sequence of numbers between the give range. range(start, stop, step)

number=range(4,-1,-1)
for i in number:
    print(i)
# Out:
# 4
# 3
# 2
# 1
# 0

# %%
num=range(1,10,3)
print(list(num))
# Out:
# [1, 4, 7]

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# # reversed()

# %%
# The reversed() method computes the reverse of a given sequence object and returns it in the form of a list.
seq="Minhaj"
print(reversed(seq))
print(list(reversed(seq)))
# Out:
# <reversed object at 0x0000018E52FC7070>
# ['j', 'a', 'h', 'n', 'i', 'M']

# %% [markdown]
# # property()

# %%
class Person:
    def __init__(self,name):
        self._name=name
    def get_name(self):
        print('Getting name')
        return self._name
    def set_name(self,value):
        print('set name to'+ value)
        self._name=value
    def del_name(self):
        print('Deleting name')
        del self._name
        
    name=property(get_name,set_name,del_name,'Name property')
    
p=Person('Minhaj')
print(p.name)
p.name='Asma'
del p.name

# As shown in the program, referencing p.name internally calls get_name() as getter, set_name() as
# setter and del_name() as deleter through the printed output present inside the methods.
# Out:
# Getting name
# Minhaj
# set name toAsma
# Deleting name

# %%
class Person:
    def __init__(self,name):
        self._name=name
    def get_name(self):
        print('getting name')
        return self._name
    def set_name(self,value):
        print('set name to '+ value)
        self._name=value
    def del_name(self):
        print('delete name')

        del self._name
        
    name=property(get_name,set_name,del_name,'Name peroperty')
pr=Person('Suraiya')
print(pr.name)
pr.name='Shifa'
del pr.name
# Out:
# getting name
# Suraiya
# set name to Shifa
# delete name

# %%
class Person:
    def __init__(self,name):
        self._name=name
        
    @property    
    def name(self):
        print('Getting name')
        return self._name
    @name.setter
    def name(self,value):
        print('Setting name to '+ value)
        self._name=value
    @name.deleter
    def name(self):
        print('Deleting name',self._name)
        del self._name
        
p1=Person('Amziya')
print('The name is', p1.name)

p1.name='Yashfeen'
del p1.name
# Out:
# Getting name
# The name is Amziya
# Setting name to Yashfeen
# Deleting name Yashfeen

# %%
olst = [[1, 2, 3], [4, 5, 6], [7, 8, 'a']]
nlst=olst
nlst[2][2]=193
print(nlst,id(nlst))
print(olst,id(olst))
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 193]] 2264030060992
# [[1, 2, 3], [4, 5, 6], [7, 8, 193]] 2264030060992

# %% [raw]
# Essentially, sometimes you may want to have the original values unchanged and only modify the new values or vice versa.
# In Python, there are two ways to create copies:
#
# 1.Shallow Copy
# 2.Deep Copy

# %%
import copy

old_list = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
new_list = copy.copy(old_list)

print("Old list:", old_list)
print("New list:", new_list)

old_list.append([4, 4, 4])
#old_list[2][2]="minhaj"
print("Old list:", old_list)
print("New list:", new_list)
# Out:
# Old list: [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
# New list: [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
# Old list: [[1, 2, 3], [4, 5, 6], [7, 8, 9], [4, 4, 4]]
# New list: [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
import copy

old_list = [[1, 1, 1], [2, 2, 2], [3, 3, 3]]
new_list = copy.copy(old_list)

old_list[1][1] = 'AA'

print("id of Old list:", id(old_list),old_list)
print("id of New list:", id(new_list),new_list)

print('id of first element of old list',id(old_list[0]))
print('id of second element of old list',id(old_list[1]))
print('id of first element of old list',id(old_list[2]))
# Out:
# id of Old list: 2060636999424 [[1, 1, 1], [2, 'AA', 2], [3, 3, 3]]
# id of New list: 2060636998208 [[1, 1, 1], [2, 'AA', 2], [3, 3, 3]]
# id of first element of old list 2060636997696
# id of second element of old list 2060636996992
# id of first element of old list 2060636999232

# %%
import copy

old_list = [[1, 1, 1], [2, 2, 2], [3, 3, 3]]
new_list = copy.deepcopy(old_list)

old_list[1][0] = 'BB'

print("Old list:", old_list)
print("New list:", new_list)
# Out:
# Old list: [[1, 1, 1], ['BB', 2, 2], [3, 3, 3]]
# New list: [[1, 1, 1], [2, 2, 2], [3, 3, 3]]

# %%
import copy
olist = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
shallow_copy=copy.copy(olist)
deep_copy=copy.copy(olist)
#shallow_copy[0][0]=987
deep_copy[0][0]=234
print(shallow_copy)
print(deep_copy)
# Out:
# [[234, 2, 3], [4, 5, 6], [7, 8, 9]]
# [[234, 2, 3], [4, 5, 6], [7, 8, 9]]
