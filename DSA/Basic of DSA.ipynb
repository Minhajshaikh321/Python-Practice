# %% [markdown]
# # What are data structure

# %% [raw]
# A Data Structure is a way of storing and organizing data so operations become efficient.

# %% [markdown]
# # Why do we need data structures?

# %% [raw]
# 1.To store data efficiently
# 2.To fetch data faster
# 3.To reduce memory usage
# 4.To handle big applications (Netflix, Google, Amazon)
# 5.there types are Array,Linked List,Queue,Hash map,Stack

# %% [markdown]
# # What is an algorithm?

# %% [raw]
# An Algorithm is a step-by-step method to solve a problem.

# %% [raw]
# Examples:
# Searching for a contact → search algorithm
# Sorting marks from low to high → sorting algorithm
# Finding a route in Google Maps → graph algorithm

# %% [markdown]
# # Time & space complexity

# %% [raw]
# This tells us how fast or how slow an algorithm runs as input size grows.

# %% [raw]
# Why Big-O is needed?
# Because code can be:
# 1.Fast for small inputs
# 2.Slow for large inputs
# We measure efficiency, not CPU time.
